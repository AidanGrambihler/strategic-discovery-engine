# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from dsr_analysis.data_loader import load_master_table, load_seattle_geometry
from dsr_analysis.models import fit_dsr_models
from dsr_analysis.spatial import plot_residuals, calculate_spatial_autocorrelation

# Set global plotting style
plt.style.use('seaborn-v0_8-whitegrid')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Digital-to-Social Ratio (DSR) Analysis
# Objective: To determine if the perceived reliability of digital infrastructure (ISP quality) correlates with a shift from digital-only activity to physical-social presence in Seattle. Hypothesis: Areas with higher internet reliability scores will show a higher DSR, suggesting "reliable connectivity" is a prerequisite for high-quality public life.

# %%
# Load standardized datasets
df = load_master_table("data/processed/master_table.csv")
gdf = load_seattle_geometry("data/raw/seattle_zip_codes_trimmed.geojson")

print(f"Dataset loaded: {len(df)} observations across {df['zip_code'].nunique()} ZIP codes.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Load standardized datasets
# ----> 2 df = load_master_table("data/processed/master_table.csv")
#       3 gdf = load_seattle_geometry("data/raw/seattle_zip_codes_trimmed.geojson")
#       5 print(f"Dataset loaded: {len(df)} observations across {df['zip_code'].nunique()} ZIP codes.")
#
# File ~/seattle-public-life-analysis/dsr_analysis/data_loader.py:10, in load_master_table(path)
#       7 # Setup logging for the module
#       8 logger = logging.getLogger(__name__)
# ---> 10 # --- Metadata Schemas (Kept in-file as requested) ---
#      11 RELIABILITY_DESC = {5: "Completely Adequate", 4: "Mostly Adequate", 3: "Sometimes Adequate", 2: "Rarely Adequate",
#      12                     1: "Not Adequate"}
# ...

# %%
# Fit the OLS and Mixed-Effects models
results = fit_dsr_models(df)

# Display the primary Baseline result
results['baseline'].summary()
